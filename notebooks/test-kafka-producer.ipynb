# %% [markdown]
# # Producer

# %%
from confluent_kafka import Producer
import time
import random
from datetime import datetime, timezone

from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Configuração do Kafka
kafka_broker = "kafka-cpc.certi.org.br:31289"  # Use o serviço bootstrap do Kafka
topic_name = "iot-temperature"

# Configuração do produtor
producer_config = {
    'bootstrap.servers': kafka_broker,
    'client.id': 'iot-producer'
}
producer = Producer(producer_config)

def delivery_report(err, msg):
    """Callback de confirmação de entrega."""
    if err is not None:
        print(f"Erro na entrega: {err}")
    else:
        print(f"Mensagem entregue para {msg.topic()} [{msg.partition()}]")

print("Enviando dados para o Kafka... Pressione Ctrl+C para parar.")

try:
    while True:
        # Simula dados do sensor
        temperature = round(random.uniform(20.0, 30.0), 2)
        timestamp = datetime.now(timezone.utc).isoformat()
        message = f'{{"timestamp": "{timestamp}", "temperature": {temperature}}}'

        print(f"Message sent: {message}")
        # Envia para o Kafka
        producer.produce(topic_name, key=str(time.time()), value=message, callback=delivery_report)
        producer.poll(0)

        # Aguarda 1 segundo antes de enviar o próximo dado
        time.sleep(1)
except KeyboardInterrupt:
    print("Parando o produtor...")
finally:
    producer.flush()
# Out:
# Enviando dados para o Kafka... Pressione Ctrl+C para parar.
# Message sent: {"timestamp": "2025-01-16T17:00:02.489795+00:00", "temperature": 25.65}
# Message sent: {"timestamp": "2025-01-16T17:00:03.490017+00:00", "temperature": 20.53}
# Message sent: {"timestamp": "2025-01-16T17:00:04.490305+00:00", "temperature": 28.15}
# Mensagem entregue para iot-temperature [13]
# Mensagem entregue para iot-temperature [1]
# Message sent: {"timestamp": "2025-01-16T17:00:05.490810+00:00", "temperature": 25.85}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:00:06.491492+00:00", "temperature": 25.83}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:00:07.492273+00:00", "temperature": 20.4}
# Mensagem entregue para iot-temperature [11]
# Message sent: {"timestamp": "2025-01-16T17:00:08.492715+00:00", "temperature": 21.99}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:00:09.493036+00:00", "temperature": 24.97}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:00:10.493371+00:00", "temperature": 24.63}
# Mensagem entregue para iot-temperature [3]
# Message sent: {"timestamp": "2025-01-16T17:00:11.493808+00:00", "temperature": 20.21}
# Mensagem entregue para iot-temperature [7]
# Message sent: {"timestamp": "2025-01-16T17:00:12.494108+00:00", "temperature": 24.07}
# Mensagem entregue para iot-temperature [4]
# Message sent: {"timestamp": "2025-01-16T17:00:13.494442+00:00", "temperature": 25.92}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:00:14.495030+00:00", "temperature": 24.31}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:00:15.495393+00:00", "temperature": 23.08}
# Mensagem entregue para iot-temperature [4]
# Message sent: {"timestamp": "2025-01-16T17:00:16.495908+00:00", "temperature": 24.52}
# Mensagem entregue para iot-temperature [1]
# Message sent: {"timestamp": "2025-01-16T17:00:17.497161+00:00", "temperature": 27.97}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:00:18.498001+00:00", "temperature": 20.13}
# Mensagem entregue para iot-temperature [13]
# Message sent: {"timestamp": "2025-01-16T17:00:19.498563+00:00", "temperature": 20.61}
# Mensagem entregue para iot-temperature [14]
# Message sent: {"timestamp": "2025-01-16T17:00:20.499108+00:00", "temperature": 29.34}
# Mensagem entregue para iot-temperature [10]
# Message sent: {"timestamp": "2025-01-16T17:00:21.499463+00:00", "temperature": 22.05}
# Mensagem entregue para iot-temperature [3]
# Message sent: {"timestamp": "2025-01-16T17:00:22.500188+00:00", "temperature": 20.8}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:00:23.500848+00:00", "temperature": 25.03}
# Mensagem entregue para iot-temperature [14]
# Message sent: {"timestamp": "2025-01-16T17:00:24.502318+00:00", "temperature": 27.86}
# Mensagem entregue para iot-temperature [10]
# Message sent: {"timestamp": "2025-01-16T17:00:25.502711+00:00", "temperature": 20.44}
# Mensagem entregue para iot-temperature [4]
# Message sent: {"timestamp": "2025-01-16T17:00:26.503298+00:00", "temperature": 24.5}
# Mensagem entregue para iot-temperature [3]
# Message sent: {"timestamp": "2025-01-16T17:00:27.504001+00:00", "temperature": 23.8}
# Mensagem entregue para iot-temperature [13]
# Message sent: {"timestamp": "2025-01-16T17:00:28.504653+00:00", "temperature": 21.88}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:00:29.505502+00:00", "temperature": 28.13}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:00:30.505882+00:00", "temperature": 29.52}
# Mensagem entregue para iot-temperature [11]
# Message sent: {"timestamp": "2025-01-16T17:00:31.506498+00:00", "temperature": 25.98}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:00:32.506832+00:00", "temperature": 27.05}
# Mensagem entregue para iot-temperature [2]
# Message sent: {"timestamp": "2025-01-16T17:00:33.507201+00:00", "temperature": 22.67}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:00:34.507983+00:00", "temperature": 25.45}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:00:35.508489+00:00", "temperature": 20.58}
# Mensagem entregue para iot-temperature [4]
# Message sent: {"timestamp": "2025-01-16T17:00:36.509087+00:00", "temperature": 28.43}
# Mensagem entregue para iot-temperature [2]
# Message sent: {"timestamp": "2025-01-16T17:00:37.509443+00:00", "temperature": 29.39}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:00:38.509954+00:00", "temperature": 26.61}
# Mensagem entregue para iot-temperature [1]
# Message sent: {"timestamp": "2025-01-16T17:00:39.510492+00:00", "temperature": 20.36}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:00:40.510955+00:00", "temperature": 29.36}
# Mensagem entregue para iot-temperature [14]
# Message sent: {"timestamp": "2025-01-16T17:00:41.511249+00:00", "temperature": 21.8}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:00:42.511556+00:00", "temperature": 27.66}
# Mensagem entregue para iot-temperature [3]
# Message sent: {"timestamp": "2025-01-16T17:00:43.512117+00:00", "temperature": 26.07}
# Mensagem entregue para iot-temperature [11]
# Message sent: {"timestamp": "2025-01-16T17:00:44.512717+00:00", "temperature": 26.54}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:00:45.513577+00:00", "temperature": 25.48}
# Mensagem entregue para iot-temperature [11]
# Message sent: {"timestamp": "2025-01-16T17:00:46.514040+00:00", "temperature": 27.49}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:00:47.514414+00:00", "temperature": 23.28}
# Mensagem entregue para iot-temperature [7]
# Message sent: {"timestamp": "2025-01-16T17:00:48.515114+00:00", "temperature": 20.4}
# Mensagem entregue para iot-temperature [3]
# Message sent: {"timestamp": "2025-01-16T17:00:49.515756+00:00", "temperature": 28.33}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:00:50.516333+00:00", "temperature": 28.93}
# Mensagem entregue para iot-temperature [7]
# Message sent: {"timestamp": "2025-01-16T17:00:51.516626+00:00", "temperature": 20.07}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:00:52.517154+00:00", "temperature": 26.2}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:00:53.517643+00:00", "temperature": 22.73}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:00:54.518113+00:00", "temperature": 28.6}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:00:55.518497+00:00", "temperature": 20.18}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:00:56.518781+00:00", "temperature": 27.74}
# Mensagem entregue para iot-temperature [3]
# Message sent: {"timestamp": "2025-01-16T17:00:57.519089+00:00", "temperature": 23.8}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:00:58.519573+00:00", "temperature": 28.51}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:00:59.520260+00:00", "temperature": 22.41}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:01:00.520672+00:00", "temperature": 26.85}
# Mensagem entregue para iot-temperature [4]
# Message sent: {"timestamp": "2025-01-16T17:01:01.520979+00:00", "temperature": 25.6}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:01:02.521430+00:00", "temperature": 20.99}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:01:03.522704+00:00", "temperature": 24.63}
# Mensagem entregue para iot-temperature [7]
# Message sent: {"timestamp": "2025-01-16T17:01:04.523336+00:00", "temperature": 23.87}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:01:05.523993+00:00", "temperature": 24.7}
# Mensagem entregue para iot-temperature [10]
# Message sent: {"timestamp": "2025-01-16T17:01:06.524464+00:00", "temperature": 25.51}
# Mensagem entregue para iot-temperature [14]
# Message sent: {"timestamp": "2025-01-16T17:01:07.525123+00:00", "temperature": 26.89}
# Mensagem entregue para iot-temperature [2]
# Message sent: {"timestamp": "2025-01-16T17:01:08.525999+00:00", "temperature": 28.01}
# Mensagem entregue para iot-temperature [3]
# Message sent: {"timestamp": "2025-01-16T17:01:09.526941+00:00", "temperature": 23.43}
# Mensagem entregue para iot-temperature [3]
# Message sent: {"timestamp": "2025-01-16T17:01:10.527962+00:00", "temperature": 28.18}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:01:11.528626+00:00", "temperature": 21.74}
# Mensagem entregue para iot-temperature [7]
# Message sent: {"timestamp": "2025-01-16T17:01:12.529023+00:00", "temperature": 23.24}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:01:13.529665+00:00", "temperature": 24.77}
# Mensagem entregue para iot-temperature [14]
# Message sent: {"timestamp": "2025-01-16T17:01:14.529982+00:00", "temperature": 21.67}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:01:15.530476+00:00", "temperature": 28.99}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:01:16.530857+00:00", "temperature": 25.62}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:01:17.531234+00:00", "temperature": 27.81}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:01:18.531727+00:00", "temperature": 22.76}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:01:19.532275+00:00", "temperature": 29.23}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:01:20.532939+00:00", "temperature": 29.38}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:01:21.533643+00:00", "temperature": 20.94}
# Mensagem entregue para iot-temperature [13]
# Message sent: {"timestamp": "2025-01-16T17:01:22.534566+00:00", "temperature": 24.68}
# Mensagem entregue para iot-temperature [1]
# Message sent: {"timestamp": "2025-01-16T17:01:23.535334+00:00", "temperature": 25.9}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:01:24.536072+00:00", "temperature": 27.49}
# Mensagem entregue para iot-temperature [4]
# Message sent: {"timestamp": "2025-01-16T17:01:25.536767+00:00", "temperature": 23.24}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:01:26.537178+00:00", "temperature": 20.44}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:01:27.537774+00:00", "temperature": 27.95}
# Mensagem entregue para iot-temperature [13]
# Message sent: {"timestamp": "2025-01-16T17:01:28.538283+00:00", "temperature": 29.09}
# Mensagem entregue para iot-temperature [3]
# Message sent: {"timestamp": "2025-01-16T17:01:29.538793+00:00", "temperature": 22.4}
# Mensagem entregue para iot-temperature [13]
# Message sent: {"timestamp": "2025-01-16T17:01:30.539109+00:00", "temperature": 29.38}
# Mensagem entregue para iot-temperature [2]
# Message sent: {"timestamp": "2025-01-16T17:01:31.539554+00:00", "temperature": 22.57}
# Mensagem entregue para iot-temperature [13]
# Message sent: {"timestamp": "2025-01-16T17:01:32.539870+00:00", "temperature": 21.71}
# Mensagem entregue para iot-temperature [11]
# Message sent: {"timestamp": "2025-01-16T17:01:33.540294+00:00", "temperature": 27.11}
# Mensagem entregue para iot-temperature [4]
# Message sent: {"timestamp": "2025-01-16T17:01:34.540858+00:00", "temperature": 28.2}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:01:35.541589+00:00", "temperature": 25.5}
# Mensagem entregue para iot-temperature [3]
# Message sent: {"timestamp": "2025-01-16T17:01:36.541887+00:00", "temperature": 29.56}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:01:37.542157+00:00", "temperature": 25.16}
# Mensagem entregue para iot-temperature [1]
# Message sent: {"timestamp": "2025-01-16T17:01:38.542461+00:00", "temperature": 25.85}
# Mensagem entregue para iot-temperature [4]
# Message sent: {"timestamp": "2025-01-16T17:01:39.542788+00:00", "temperature": 24.34}
# Mensagem entregue para iot-temperature [7]
# Message sent: {"timestamp": "2025-01-16T17:01:40.543426+00:00", "temperature": 29.87}
# Mensagem entregue para iot-temperature [13]
# Message sent: {"timestamp": "2025-01-16T17:01:41.544161+00:00", "temperature": 21.83}
# Mensagem entregue para iot-temperature [2]
# Message sent: {"timestamp": "2025-01-16T17:01:42.545103+00:00", "temperature": 24.09}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:01:43.545492+00:00", "temperature": 21.87}
# Mensagem entregue para iot-temperature [4]
# Message sent: {"timestamp": "2025-01-16T17:01:44.546108+00:00", "temperature": 25.76}
# Mensagem entregue para iot-temperature [14]
# Message sent: {"timestamp": "2025-01-16T17:01:45.546448+00:00", "temperature": 23.3}
# Mensagem entregue para iot-temperature [13]
# Message sent: {"timestamp": "2025-01-16T17:01:46.546949+00:00", "temperature": 26.93}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:01:47.547289+00:00", "temperature": 25.04}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:01:48.547986+00:00", "temperature": 20.09}
# Mensagem entregue para iot-temperature [3]
# Message sent: {"timestamp": "2025-01-16T17:01:49.548748+00:00", "temperature": 22.29}
# Mensagem entregue para iot-temperature [7]
# Message sent: {"timestamp": "2025-01-16T17:01:50.549155+00:00", "temperature": 20.81}
# Mensagem entregue para iot-temperature [1]
# Message sent: {"timestamp": "2025-01-16T17:01:51.549508+00:00", "temperature": 23.16}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:01:52.550095+00:00", "temperature": 21.15}
# Mensagem entregue para iot-temperature [11]
# Message sent: {"timestamp": "2025-01-16T17:01:53.550700+00:00", "temperature": 29.11}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:01:54.552260+00:00", "temperature": 22.21}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:01:55.552790+00:00", "temperature": 23.31}
# Mensagem entregue para iot-temperature [4]
# Message sent: {"timestamp": "2025-01-16T17:01:56.553527+00:00", "temperature": 25.75}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:01:57.554052+00:00", "temperature": 22.34}
# Mensagem entregue para iot-temperature [7]
# Message sent: {"timestamp": "2025-01-16T17:01:58.554581+00:00", "temperature": 26.6}
# Mensagem entregue para iot-temperature [14]
# Message sent: {"timestamp": "2025-01-16T17:01:59.555107+00:00", "temperature": 23.33}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:02:00.555981+00:00", "temperature": 24.81}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:02:01.556339+00:00", "temperature": 29.21}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:02:02.556708+00:00", "temperature": 22.79}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:02:03.557314+00:00", "temperature": 28.7}
# Mensagem entregue para iot-temperature [7]
# Message sent: {"timestamp": "2025-01-16T17:02:04.557730+00:00", "temperature": 26.34}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:02:05.558063+00:00", "temperature": 23.63}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:02:06.558367+00:00", "temperature": 25.41}
# Mensagem entregue para iot-temperature [13]
# Message sent: {"timestamp": "2025-01-16T17:02:07.558729+00:00", "temperature": 22.41}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:02:08.559110+00:00", "temperature": 22.89}
# Mensagem entregue para iot-temperature [4]
# Message sent: {"timestamp": "2025-01-16T17:02:09.559461+00:00", "temperature": 24.07}
# Mensagem entregue para iot-temperature [10]
# Message sent: {"timestamp": "2025-01-16T17:02:10.559996+00:00", "temperature": 20.47}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:02:11.560528+00:00", "temperature": 21.52}
# Mensagem entregue para iot-temperature [7]
# Message sent: {"timestamp": "2025-01-16T17:02:12.560901+00:00", "temperature": 25.11}
# Mensagem entregue para iot-temperature [1]
# Message sent: {"timestamp": "2025-01-16T17:02:13.561222+00:00", "temperature": 22.54}
# Mensagem entregue para iot-temperature [13]
# Message sent: {"timestamp": "2025-01-16T17:02:14.561502+00:00", "temperature": 22.97}
# Mensagem entregue para iot-temperature [1]
# Message sent: {"timestamp": "2025-01-16T17:02:15.561775+00:00", "temperature": 21.47}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:02:16.562329+00:00", "temperature": 21.02}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:02:17.562783+00:00", "temperature": 24.96}
# Mensagem entregue para iot-temperature [7]
# Message sent: {"timestamp": "2025-01-16T17:02:18.563356+00:00", "temperature": 27.64}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:02:19.564102+00:00", "temperature": 20.65}
# Mensagem entregue para iot-temperature [2]
# Message sent: {"timestamp": "2025-01-16T17:02:20.564634+00:00", "temperature": 21.22}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:02:21.565286+00:00", "temperature": 25.25}
# Mensagem entregue para iot-temperature [11]
# Message sent: {"timestamp": "2025-01-16T17:02:22.566138+00:00", "temperature": 24.01}
# Mensagem entregue para iot-temperature [10]
# Message sent: {"timestamp": "2025-01-16T17:02:23.567106+00:00", "temperature": 24.98}
# Mensagem entregue para iot-temperature [1]
# Message sent: {"timestamp": "2025-01-16T17:02:24.568573+00:00", "temperature": 20.82}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:02:25.569316+00:00", "temperature": 20.24}
# Mensagem entregue para iot-temperature [11]
# Message sent: {"timestamp": "2025-01-16T17:02:26.570022+00:00", "temperature": 20.59}
# Mensagem entregue para iot-temperature [14]
# Message sent: {"timestamp": "2025-01-16T17:02:27.570607+00:00", "temperature": 21.04}
# Mensagem entregue para iot-temperature [2]
# Message sent: {"timestamp": "2025-01-16T17:02:28.570971+00:00", "temperature": 28.27}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:02:29.571563+00:00", "temperature": 29.46}
# Mensagem entregue para iot-temperature [3]
# Message sent: {"timestamp": "2025-01-16T17:02:30.572044+00:00", "temperature": 22.0}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:02:31.572672+00:00", "temperature": 24.76}
# Mensagem entregue para iot-temperature [3]
# Message sent: {"timestamp": "2025-01-16T17:02:32.573060+00:00", "temperature": 27.05}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:02:33.573383+00:00", "temperature": 23.18}
# Mensagem entregue para iot-temperature [13]
# Message sent: {"timestamp": "2025-01-16T17:02:34.573831+00:00", "temperature": 26.02}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:02:35.574198+00:00", "temperature": 28.11}
# Mensagem entregue para iot-temperature [3]
# Message sent: {"timestamp": "2025-01-16T17:02:36.574796+00:00", "temperature": 22.56}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:02:37.575250+00:00", "temperature": 28.41}
# Mensagem entregue para iot-temperature [14]
# Message sent: {"timestamp": "2025-01-16T17:02:38.576224+00:00", "temperature": 22.3}
# Mensagem entregue para iot-temperature [11]
# Message sent: {"timestamp": "2025-01-16T17:02:39.576644+00:00", "temperature": 27.27}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:02:40.577637+00:00", "temperature": 23.94}
# Mensagem entregue para iot-temperature [11]
# Message sent: {"timestamp": "2025-01-16T17:02:41.578641+00:00", "temperature": 29.35}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:02:42.579482+00:00", "temperature": 20.51}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:02:43.580239+00:00", "temperature": 24.61}
# Mensagem entregue para iot-temperature [2]
# Message sent: {"timestamp": "2025-01-16T17:02:44.581101+00:00", "temperature": 29.52}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:02:45.581423+00:00", "temperature": 21.81}
# Mensagem entregue para iot-temperature [14]
# Message sent: {"timestamp": "2025-01-16T17:02:46.581966+00:00", "temperature": 29.68}
# Mensagem entregue para iot-temperature [10]
# Message sent: {"timestamp": "2025-01-16T17:02:47.582741+00:00", "temperature": 28.93}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:02:48.583280+00:00", "temperature": 28.37}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:02:49.584152+00:00", "temperature": 23.13}
# Mensagem entregue para iot-temperature [11]
# Message sent: {"timestamp": "2025-01-16T17:02:50.584909+00:00", "temperature": 21.23}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:02:51.585480+00:00", "temperature": 23.63}
# Mensagem entregue para iot-temperature [11]
# Message sent: {"timestamp": "2025-01-16T17:02:52.586138+00:00", "temperature": 27.23}
# Mensagem entregue para iot-temperature [10]
# Message sent: {"timestamp": "2025-01-16T17:02:53.586986+00:00", "temperature": 27.86}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:02:54.587525+00:00", "temperature": 24.38}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:02:55.588045+00:00", "temperature": 23.85}
# Mensagem entregue para iot-temperature [10]
# Message sent: {"timestamp": "2025-01-16T17:02:56.588782+00:00", "temperature": 28.07}
# Mensagem entregue para iot-temperature [10]
# Message sent: {"timestamp": "2025-01-16T17:02:57.589298+00:00", "temperature": 27.82}
# Mensagem entregue para iot-temperature [14]
# Message sent: {"timestamp": "2025-01-16T17:02:58.590122+00:00", "temperature": 25.93}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:02:59.591151+00:00", "temperature": 20.8}
# Mensagem entregue para iot-temperature [1]
# Message sent: {"timestamp": "2025-01-16T17:03:00.592091+00:00", "temperature": 29.76}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:03:01.592715+00:00", "temperature": 29.87}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:03:02.593181+00:00", "temperature": 22.48}
# Mensagem entregue para iot-temperature [4]
# Message sent: {"timestamp": "2025-01-16T17:03:03.593824+00:00", "temperature": 25.54}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:03:04.594355+00:00", "temperature": 27.81}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:03:05.594915+00:00", "temperature": 22.46}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:03:06.595648+00:00", "temperature": 24.59}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:03:07.596163+00:00", "temperature": 26.61}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:03:08.596769+00:00", "temperature": 29.6}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:03:09.597493+00:00", "temperature": 26.74}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:03:10.597980+00:00", "temperature": 26.03}
# Mensagem entregue para iot-temperature [13]
# Message sent: {"timestamp": "2025-01-16T17:03:11.598325+00:00", "temperature": 23.84}
# Mensagem entregue para iot-temperature [1]
# Message sent: {"timestamp": "2025-01-16T17:03:12.598723+00:00", "temperature": 25.48}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:03:13.599115+00:00", "temperature": 27.37}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:03:14.599815+00:00", "temperature": 28.45}
# Mensagem entregue para iot-temperature [14]
# Message sent: {"timestamp": "2025-01-16T17:03:15.600541+00:00", "temperature": 23.98}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:03:16.600903+00:00", "temperature": 23.9}
# Mensagem entregue para iot-temperature [7]
# Message sent: {"timestamp": "2025-01-16T17:03:17.601654+00:00", "temperature": 28.22}
# Mensagem entregue para iot-temperature [4]
# Message sent: {"timestamp": "2025-01-16T17:03:18.602116+00:00", "temperature": 24.13}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:03:19.602861+00:00", "temperature": 23.75}
# Mensagem entregue para iot-temperature [11]
# Message sent: {"timestamp": "2025-01-16T17:03:20.603363+00:00", "temperature": 23.97}
# Mensagem entregue para iot-temperature [7]
# Message sent: {"timestamp": "2025-01-16T17:03:21.604194+00:00", "temperature": 23.52}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:03:22.604861+00:00", "temperature": 27.4}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:03:23.605217+00:00", "temperature": 23.24}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:03:24.605788+00:00", "temperature": 22.11}
# Mensagem entregue para iot-temperature [4]
# Message sent: {"timestamp": "2025-01-16T17:03:25.606371+00:00", "temperature": 24.03}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:03:26.607219+00:00", "temperature": 20.87}
# Mensagem entregue para iot-temperature [10]
# Message sent: {"timestamp": "2025-01-16T17:03:27.608161+00:00", "temperature": 21.97}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:03:28.609008+00:00", "temperature": 21.57}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:03:29.609710+00:00", "temperature": 28.0}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:03:30.610197+00:00", "temperature": 20.53}
# Mensagem entregue para iot-temperature [7]
# Message sent: {"timestamp": "2025-01-16T17:03:31.610821+00:00", "temperature": 25.67}
# Mensagem entregue para iot-temperature [3]
# Message sent: {"timestamp": "2025-01-16T17:03:32.611317+00:00", "temperature": 27.79}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:03:33.611888+00:00", "temperature": 26.47}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:03:34.612359+00:00", "temperature": 28.66}
# Mensagem entregue para iot-temperature [3]
# Message sent: {"timestamp": "2025-01-16T17:03:35.612795+00:00", "temperature": 24.77}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:03:36.613093+00:00", "temperature": 27.11}
# Mensagem entregue para iot-temperature [7]
# Message sent: {"timestamp": "2025-01-16T17:03:37.613565+00:00", "temperature": 22.37}
# Mensagem entregue para iot-temperature [2]
# Message sent: {"timestamp": "2025-01-16T17:03:38.614132+00:00", "temperature": 23.44}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:03:39.614831+00:00", "temperature": 27.88}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:03:40.615339+00:00", "temperature": 25.01}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:03:41.616420+00:00", "temperature": 23.09}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:03:42.617158+00:00", "temperature": 23.07}
# Mensagem entregue para iot-temperature [13]
# Message sent: {"timestamp": "2025-01-16T17:03:43.617484+00:00", "temperature": 26.84}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:03:44.617819+00:00", "temperature": 23.94}
# Mensagem entregue para iot-temperature [2]
# Message sent: {"timestamp": "2025-01-16T17:03:45.618336+00:00", "temperature": 25.56}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:03:46.619260+00:00", "temperature": 27.09}
# Mensagem entregue para iot-temperature [2]
# Message sent: {"timestamp": "2025-01-16T17:03:47.620229+00:00", "temperature": 24.57}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:03:48.621230+00:00", "temperature": 29.99}
# Mensagem entregue para iot-temperature [2]
# Message sent: {"timestamp": "2025-01-16T17:03:49.622202+00:00", "temperature": 23.98}
# Mensagem entregue para iot-temperature [10]
# Message sent: {"timestamp": "2025-01-16T17:03:50.622836+00:00", "temperature": 24.12}
# Mensagem entregue para iot-temperature [2]
# Message sent: {"timestamp": "2025-01-16T17:03:51.623373+00:00", "temperature": 20.2}
# Mensagem entregue para iot-temperature [4]
# Message sent: {"timestamp": "2025-01-16T17:03:52.623741+00:00", "temperature": 29.33}
# Mensagem entregue para iot-temperature [4]
# Message sent: {"timestamp": "2025-01-16T17:03:53.624319+00:00", "temperature": 29.8}
# Mensagem entregue para iot-temperature [7]
# Message sent: {"timestamp": "2025-01-16T17:03:54.624744+00:00", "temperature": 29.49}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:03:55.625715+00:00", "temperature": 29.45}
# Mensagem entregue para iot-temperature [13]
# Message sent: {"timestamp": "2025-01-16T17:03:56.626462+00:00", "temperature": 21.88}
# Mensagem entregue para iot-temperature [2]
# Message sent: {"timestamp": "2025-01-16T17:03:57.626848+00:00", "temperature": 26.91}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:03:58.627248+00:00", "temperature": 21.37}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:03:59.627796+00:00", "temperature": 21.98}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:04:00.628069+00:00", "temperature": 21.23}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:04:01.628803+00:00", "temperature": 21.88}
# Mensagem entregue para iot-temperature [3]
# Message sent: {"timestamp": "2025-01-16T17:04:02.629505+00:00", "temperature": 26.07}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:04:03.630103+00:00", "temperature": 20.77}
# Mensagem entregue para iot-temperature [2]
# Message sent: {"timestamp": "2025-01-16T17:04:04.630636+00:00", "temperature": 28.32}
# Mensagem entregue para iot-temperature [10]
# Message sent: {"timestamp": "2025-01-16T17:04:05.630969+00:00", "temperature": 28.18}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:04:06.631686+00:00", "temperature": 21.95}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:04:07.632097+00:00", "temperature": 23.55}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:04:08.632888+00:00", "temperature": 21.89}
# Mensagem entregue para iot-temperature [1]
# Message sent: {"timestamp": "2025-01-16T17:04:09.633570+00:00", "temperature": 23.65}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:04:10.633993+00:00", "temperature": 20.52}
# Mensagem entregue para iot-temperature [3]
# Message sent: {"timestamp": "2025-01-16T17:04:11.634704+00:00", "temperature": 21.57}
# Mensagem entregue para iot-temperature [10]
# Message sent: {"timestamp": "2025-01-16T17:04:12.635606+00:00", "temperature": 27.62}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:04:13.636067+00:00", "temperature": 22.78}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:04:14.636405+00:00", "temperature": 21.26}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:04:15.636958+00:00", "temperature": 23.33}
# Mensagem entregue para iot-temperature [10]
# Message sent: {"timestamp": "2025-01-16T17:04:16.637697+00:00", "temperature": 22.6}
# Mensagem entregue para iot-temperature [2]
# Message sent: {"timestamp": "2025-01-16T17:04:17.638228+00:00", "temperature": 22.35}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:04:18.638765+00:00", "temperature": 20.51}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:04:19.639067+00:00", "temperature": 20.9}
# Mensagem entregue para iot-temperature [11]
# Message sent: {"timestamp": "2025-01-16T17:04:20.639692+00:00", "temperature": 26.21}
# Mensagem entregue para iot-temperature [3]
# Message sent: {"timestamp": "2025-01-16T17:04:21.640333+00:00", "temperature": 21.23}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:04:22.640978+00:00", "temperature": 26.97}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:04:23.641875+00:00", "temperature": 27.31}
# Mensagem entregue para iot-temperature [12]
# Message sent: {"timestamp": "2025-01-16T17:04:24.642452+00:00", "temperature": 20.59}
# Mensagem entregue para iot-temperature [4]
# Message sent: {"timestamp": "2025-01-16T17:04:25.643345+00:00", "temperature": 24.98}
# Mensagem entregue para iot-temperature [2]
# Message sent: {"timestamp": "2025-01-16T17:04:26.643712+00:00", "temperature": 29.37}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:04:27.644141+00:00", "temperature": 29.14}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:04:28.644505+00:00", "temperature": 23.01}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:04:29.644907+00:00", "temperature": 29.92}
# Mensagem entregue para iot-temperature [1]
# Message sent: {"timestamp": "2025-01-16T17:04:30.645251+00:00", "temperature": 22.14}
# Mensagem entregue para iot-temperature [7]
# Message sent: {"timestamp": "2025-01-16T17:04:31.645948+00:00", "temperature": 22.57}
# Mensagem entregue para iot-temperature [2]
# Message sent: {"timestamp": "2025-01-16T17:04:32.646737+00:00", "temperature": 24.99}
# Mensagem entregue para iot-temperature [10]
# Message sent: {"timestamp": "2025-01-16T17:04:33.647330+00:00", "temperature": 29.65}
# Mensagem entregue para iot-temperature [9]
# Message sent: {"timestamp": "2025-01-16T17:04:34.648054+00:00", "temperature": 29.51}
# Mensagem entregue para iot-temperature [0]
# Message sent: {"timestamp": "2025-01-16T17:04:35.648613+00:00", "temperature": 25.07}
# Mensagem entregue para iot-temperature [8]
# Message sent: {"timestamp": "2025-01-16T17:04:36.649870+00:00", "temperature": 28.74}
# Mensagem entregue para iot-temperature [2]
# Message sent: {"timestamp": "2025-01-16T17:04:37.650299+00:00", "temperature": 23.61}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:04:38.651396+00:00", "temperature": 27.56}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:04:39.652427+00:00", "temperature": 26.31}
# Mensagem entregue para iot-temperature [6]
# Message sent: {"timestamp": "2025-01-16T17:04:40.652768+00:00", "temperature": 21.41}
# Mensagem entregue para iot-temperature [5]
# Message sent: {"timestamp": "2025-01-16T17:04:41.653497+00:00", "temperature": 29.66}
# Mensagem entregue para iot-temperature [13]
# Message sent: {"timestamp": "2025-01-16T17:04:42.653817+00:00", "temperature": 27.29}
# Mensagem entregue para iot-temperature [13]
# Message sent: {"timestamp": "2025-01-16T17:04:43.654276+00:00", "temperature": 26.41}
# Mensagem entregue para iot-temperature [1]
# Parando o produtor...
# Mensagem entregue para iot-temperature [1]
